# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# # 1)

# %%
stats.uniform.pdf(11, loc=3, scale=11)
# Out:
# 0.09090909090909091

# %% [markdown]
# # 2)

# %%
arr = np.arange(20)
stats.expon.pdf(x = arr, scale = 10)
# Out:
# array([0.1       , 0.09048374, 0.08187308, 0.07408182, 0.067032  ,
#        0.06065307, 0.05488116, 0.04965853, 0.0449329 , 0.04065697,
#        0.03678794, 0.03328711, 0.03011942, 0.02725318, 0.0246597 ,
#        0.02231302, 0.02018965, 0.01826835, 0.01652989, 0.01495686])
